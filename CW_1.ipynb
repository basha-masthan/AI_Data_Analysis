# %%
pip install  pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
a = [1,2,3,4,5]
S = pd.Series(a)

# %%
S
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
S[2]
# Out:
# np.int64(3)

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000,20000,70000]
}

# %% [raw]
# print(data)

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   20000
# 2  Charlie   35   70000

# %% [raw]
# Series - 1 D array

# %%
x = [1,2,3,4,5]

# %%
pd.Series(x,index = ['a','b','c','d','e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000,20000,70000]
}

# %%
df = pd.DataFrame(data)

# %%
df = pd.DataFrame(df,columns=['Name','Age','Salary','Income',"Designation"],index=['a','b','c','d','e'])

# %%
df
# Out:
#   Name  Age  Salary  Income  Designation
# a  NaN  NaN     NaN     NaN          NaN
# b  NaN  NaN     NaN     NaN          NaN
# c  NaN  NaN     NaN     NaN          NaN
# d  NaN  NaN     NaN     NaN          NaN
# e  NaN  NaN     NaN     NaN          NaN

# %%
S[3]
# Out:
# np.int64(4)

# %%
df['Name']['Salary']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['Name']['Salary']
#
# ...

# %%
df['Name'][2]

# %%
df.shape

# %% [raw]
# loc - label based locator
# iloc - integer based locator

# %%
df.loc[1]

# %%
# DataFrame.loc[row label,column label]
df.loc[[0,2],['Name','Salary']]

# %%
df

# %%
df.iloc[[0,2],0:1]

# %% [markdown]
# I have DataFrame df. I want to look first row  of DataFrame,which is
# correct code snippet.
# a) df.loc[1,:]
# b) df.loc[0,:]
# c) df.iloc[1,:]
# d) df.iloc[0,:]

# %%
df.iloc[0,:]

# %%
df.loc[0,:]

# %%
import pandas as pd

# %%
wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_presidents_of_India')

# %%
commodity = pd.read_csv(r"E:\Guvi\ML\Dataset\Guvi-dataset\commodity_price (1).csv")
# Out:
# C:\Users\INTEL\AppData\Local\Temp\ipykernel_2532\3834810260.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   commodity = pd.read_csv(r"E:\Guvi\ML\Dataset\Guvi-dataset\commodity_price (1).csv")

# %%
commodity.head(10)
# Out:
#    s_no      state district    market  pincode country commodity variety  \
# 0     0  Karnataka  Belgaum    Athani   100001   India      Bull    Bull
# 1     1  Karnataka  Belgaum    Athani   100002   India      Bull    Bull
# 2     2  Karnataka  Belgaum    Athani   100003   India      Bull    Bull
# 3     3  Karnataka  Belgaum  Ramdurga   100004   India      Bull    Bull
# 4     4  Karnataka  Belgaum  Ramdurga   100005   India      BULL    Bull
# 5     5   Karnatak  Belgaum  Ramdurga   100006   India      BULL    Bull
# 6     6  Karnataka  Belgaum  Ramdurga   100007   India      BULL   Bulll
# 7     7  Karnataka  Belgaum  Ramdurga   100008   India      BULL    Bull
# 8     8  Karnataka  Belgaum  Ramdurga   100009   India      BULL    Bull
# 9     9  Karnataka  Belgaum  Ramdurga   100010   India      BULL    Bull
#
#   arrival_date  min_price  max_price  modal_price update_date
# 0   26-01-2020    20000.0    40000.0      40000.0         NaN
# ...

# %%
commodity.tail(10)
# Out:
#         s_no        state     district    market  pincode country commodity  \
# 78641  78593  West Bengal  Murshidabad  Jangipur   178594   India  Turmeric
# 78642  78594  West Bengal  Murshidabad  Jangipur   178595   India  Turmeric
# 78643  78595  West Bengal  Murshidabad  Jangipur   178596   India  Turmeric
# 78644  78596  West Bengal  Murshidabad  Jangipur   178597   India  Turmeric
# 78645  78597  West Bengal  Murshidabad  Jangipur   178598   India  Turmeric
# 78646  78598  West Bengal  Murshidabad  Jangipur   178599   India  Turmeric
# 78647  78599  West Bengal  Murshidabad  Jangipur   178600   India  Turmeric
# 78648  78600  West Bengal  Murshidabad  Jangipur   178601   India  Turmeric
# 78649  78601  West Bengal  Murshidabad  Jangipur   178602   India  Turmeric
# 78650  78602  West Bengal  Murshidabad  Jangipur   178603   India  Turmeric
#
#       variety arrival_date  min_price  max_price  modal_price update_date
# ...

# %%
commodity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78651 entries, 0 to 78650
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   s_no          78651 non-null  int64
#  1   state         78651 non-null  object
#  2   district      78651 non-null  object
#  3   market        78651 non-null  object
#  4   pincode       78651 non-null  int64
#  5   country       78651 non-null  object
#  6   commodity     78651 non-null  object
#  7   variety       78651 non-null  object
#  8   arrival_date  78651 non-null  object
#  9   min_price     78483 non-null  float64
#  10  max_price     78467 non-null  float64
#  11  modal_price   78651 non-null  float64
#  12  update_date   928 non-null    object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 7.8+ MB

# %%
commodity.describe(include='all',percentiles=[0.3,0.4,0.7])
# Out:
#                 s_no   state district      market        pincode country  \
# count   78651.000000   78651    78651       78651   78651.000000   78651
# unique           NaN      30      247         459            NaN       1
# top              NaN  Kerala    Erode  Thodupuzha            NaN   India
# freq             NaN   14335     3586        2040            NaN   78651
# mean    39324.978030     NaN      NaN         NaN  139325.978030     NaN
# std     22704.694333     NaN      NaN         NaN   22704.694333     NaN
# min         0.000000     NaN      NaN         NaN  100001.000000     NaN
# 30%     23595.000000     NaN      NaN         NaN  123596.000000     NaN
# 40%     31460.000000     NaN      NaN         NaN  131461.000000     NaN
# 50%     39325.000000     NaN      NaN         NaN  139326.000000     NaN
# 70%     55055.000000     NaN      NaN         NaN  155056.000000     NaN
# max     78602.000000     NaN      NaN         NaN  178603.000000     NaN
#
# ...

# %%
commodity.columns
# Out:
# Index(['s_no', 'state', 'district', 'market', 'pincode', 'country',
#        'commodity', 'variety', 'arrival_date', 'min_price', 'max_price',
#        'modal_price', 'update_date'],
#       dtype='object')

# %%
commodity.shape
# Out:
# (78651, 13)

# %% [markdown]
# DATA CLEANING

# %% [markdown]
# 1. Drop duplicates
# 2.Check null values or NaN
# 3.Handling missing values
# 4.Check data type
# 5. Drop the unwanted column

# %%
comd = commodity.copy()

# %%
comd.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 78646     True
# 78647     True
# 78648     True
# 78649     True
# 78650     True
# Length: 78651, dtype: bool

# %%
comd[comd.duplicated()].shape
# Out:
# (48, 13)

# %%
comd.drop_duplicates()
# Out:
#         s_no        state     district    market  pincode country commodity  \
# 0          0    Karnataka      Belgaum    Athani   100001   India      Bull
# 1          1    Karnataka      Belgaum    Athani   100002   India      Bull
# 3   05-01-2020    20000.0    25000.0      20000.0         NaN
# 4   12-01-2020    20000.0    35000.0      25000.0         NaN

# %% [markdown]
# Changing Datatypes

# %%
comd.dtypes
# Out:
# state            object
# district         object
# market           object
# pincode           int64
# country          object
# commodity        object
# variety          object
# arrival_date     object
# min_price       float64
# max_price       float64
# modal_price     float64
# update_date      object
# dtype: object

# %%
comd['state']
# Out:
# 0          Karnataka
# 1          Karnataka
# 2          Karnataka
# 3          Karnataka
# 4          Karnataka
#             ...
# 78598    West Bengal
# 78599    West Bengal
# 78600    West Bengal
# 78601    West Bengal
# 78602    West Bengal
# Name: state, Length: 78603, dtype: object

# %%
comd.arrival_date = comd.arrival_date.astype('datetime64[ns]')

# %%
comd.dtypes

# %%
comd.update_date = comd.update_date .astype('datetime64[ns]')

# %%
comd.head()

# %%
comd.state.unique()
# Out:
# array(['Karnataka', 'Karnatak', 'Karnatka', 'Tripura', 'Goa', 'Kerala',
#        'kerala', 'Karala', 'Tamil Nadu', 'Andhra Pradesh', 'Chattisgarh',
#        'Gujarat', 'Madhya Pradesh', 'Manipur', 'Odisha', 'Rajasthan',
#        'Telangana', 'Uttar Pradesh', 'Bihar', 'Chandigarh', 'Haryana',
#        'Himachal Pradesh', 'Jammu and Kashmir', 'Maharashtra',
#        'NCT of Delhi', 'Punjab', 'Uttrakhand', 'Meghalaya', 'Nagaland',
#        'West Bengal'], dtype=object)

# %%
comd.state.str.lower()

# %%
comd.state = comd.state.str.lower()

# %%
comd.state.replace(['Karnatak','Karnatka'],'karnataka',inplace=True)

# %%
comd.state.nunique()
# Out:
# 27

# %%
comd.state.unique()
# Out:
# array(['karnataka', 'tripura', 'goa', 'kerala', 'karala', 'tamil nadu',
#        'andhra pradesh', 'chattisgarh', 'gujarat', 'madhya pradesh',
#        'manipur', 'odisha', 'rajasthan', 'telangana', 'uttar pradesh',
#        'bihar', 'chandigarh', 'haryana', 'himachal pradesh',
#        'jammu and kashmir', 'maharashtra', 'nct of delhi', 'punjab',
#        'uttrakhand', 'meghalaya', 'nagaland', 'west bengal'], dtype=object)

# %%
district
# Out:
# 29

# %%
comd.state.replace(['Karala'],'kerala',inplace=True)

# %%
comd.district.nunique()
# Out:
# 246

# %%
comd.district.str.lower()
# Out:
# 0            belgaum
# 1            belgaum
# 2            belgaum
# 3            belgaum
# 4            belgaum
#             ...
# 78598    murshidabad
# 78599    murshidabad
# 78600    murshidabad
# 78601    murshidabad
# 78602    murshidabad
# Name: district, Length: 78603, dtype: object

# %%
comd.district.unique()
# Out:
# array(['Belgaum', 'Davangere', 'Dharwad', 'Hassan', 'Haveri', 'haveri',
#        'Khowai', 'north goa', 'North Goa', 'Bangalore', 'Bengalore',
#        'Bangalor', 'Chikmagalur', 'Haassan', 'Hassann', 'Mandya',
#        'Maandya', 'Mandyah', 'Mangalore(Dakshin Kannad)', 'Tumkur',
#        'Tumkoor', 'Idukky', 'Idukki', 'Iddukki', 'Kannur', 'Kasargod',
#        'Ariyalur', 'Coimbatore', 'Cuddalore', 'Dindigul', 'Erode',
#        'Namakkal', 'Salem', 'Vellore', 'Guntur', 'Kurnool', 'Bastar',
#        'Dahod', 'Rajkot', 'Bellary', 'Gadag', 'Kolar', 'Mysore',
#        'Raichur', 'Udupi', 'Alappuzha', 'Malappuram', 'Dhar', 'Bishnupur',
#        'Chandel', 'Imphal East', 'Imphal West', 'Thoubal', 'Ganjam',
#        'Jodhpur', 'Adilabad', 'Hyderabad', 'Khammam', 'Warangal',
#        'Sultanpur', 'Dhalai', 'Ernakulam', 'Angul', 'Mayurbhanja',
#        'Nowarangpur', 'Chitrakut', 'Jhansi', 'Araria', 'Gopalgang',
#        'Kishanganj', 'Patna', 'Rohtas', 'Siwan', 'Supaul',
# ...

# %%
dist = list(comd.district.unique())
dist.sort()
dist

# %%
comd.district.replace(['Havri'],'haveri',inplace = True)

# %%
goa ={'Nrth Goa':'north goa','North Goaa':'north goa','Nort Goa':'north goa'}

# %%
comd = comd.replace({'district':goa})

# %%
comd.district = comd.district.str.lower()

# %%
ds={ 'bengalore':'bangalore','bangalor':'bangalore', 'maandya':'mandya','mandyah':'mandya','haassan':'hassan','hassann':'hassan','iddukki':'idukki', 'idukky':'idukki'}

# %%
comd = comd.replace({'district':ds})

# %%
comd.district.unique()
# Out:
# array(['belgaum', 'davangere', 'dharwad', 'hassan', 'haveri', 'khowai',
#        'north goa', 'bangalore', 'chikmagalur', 'mandya',
#        'mangalore(dakshin kannad)', 'tumkur', 'tumkoor', 'idukki',
#        'kannur', 'kasargod', 'ariyalur', 'coimbatore', 'cuddalore',
#        'dindigul', 'erode', 'namakkal', 'salem', 'vellore', 'guntur',
#        'kurnool', 'bastar', 'dahod', 'rajkot', 'bellary', 'gadag',
#        'kolar', 'mysore', 'raichur', 'udupi', 'alappuzha', 'malappuram',
#        'dhar', 'bishnupur', 'chandel', 'imphal east', 'imphal west',
#        'thoubal', 'ganjam', 'jodhpur', 'adilabad', 'hyderabad', 'khammam',
#        'warangal', 'sultanpur', 'dhalai', 'ernakulam', 'angul',
#        'mayurbhanja', 'nowarangpur', 'chitrakut', 'jhansi', 'araria',
#        'gopalgang', 'kishanganj', 'patna', 'rohtas', 'siwan', 'supaul',
#        'west chambaran', 'chandigarh', 'bilaspur', 'durg', 'rajnandgaon',
#        'banaskanth', 'porbandar', 'ambala', 'faridabad', 'fatehabad',
# ...

# %%
comd.state.value_counts()
# Out:
# state
# kerala               14342
# tamil nadu           10516
# punjab                8982
# haryana               6880
# uttar pradesh         6276
# maharashtra           5742
# telangana             5686
# karnataka             4926
# himachal pradesh      2906
# rajasthan             1810
# uttrakhand            1756
# andhra pradesh        1278
# jammu and kashmir     1250
# madhya pradesh        1204
# chattisgarh           1084
# odisha                 984
# nct of delhi           742
# west bengal            624
# bihar                  498
# goa                    388
# gujarat                262
# tripura                129
# manipur                126
# chandigarh              88
# nagaland                58
# meghalaya               36
# karala                  18
# karnatak                 8
# karnatka                 4
# Name: count, dtype: int64

# %% [markdown]
# Handle with NaN values

py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   comd.max_price.fillna(comd.modal_price,inplace=True)

# %%
comd
# Out:
#              state     district    market  pincode country commodity variety  \
# 0        karnataka      Belgaum    Athani   100001   India      Bull    Bull
# 1        karnataka      Belgaum    Athani   100002   India      Bull    Bull
# 2        karnataka      Belgaum    Athani   100003   India      Bull    Bull
# 3        karnataka      Belgaum  Ramdurga   100004   India      Bull    Bull
# 4        karnataka      Belgaum  Ramdurga   100005   India      BULL    Bull
# ...            ...          ...       ...      ...     ...       ...     ...
# 78598  west bengal  Murshidabad  Jangipur   178599   India  Turmeric  Finger
# 78599  west bengal  Murshidabad  Jangipur   178600   India  Turmeric  Finger
# 78600  west bengal  Murshidabad  Jangipur   178601   India  Turmeric  Finger
# 78601  west bengal  Murshidabad  Jangipur   178602   India  Turmeric  Finger
# 78602  west bengal  Murshidabad  Jangipur   178603   India  Turmeric  Finger
#
# ...

# %%
comd.drop(['country','pincode'],axis = 1,inplace = True)

# %%
comd.head()
# Out:
#        state district    market commodity variety arrival_date  min_price  \
# 0  karnataka  belgaum    Athani      Bull    Bull   2020-01-26    20000.0
# 1  karnataka  belgaum    Athani      Bull    Bull   2020-02-16    10000.0
# 2  karnataka  belgaum    Athani      Bull    Bull   2020-01-03    32000.0
# 3  karnataka  belgaum  Ramdurga      Bull    Bull   2020-05-01    20000.0
# 4  karnataka  belgaum  Ramdurga      BULL    Bull   2020-12-01    20000.0
#
#    max_price  modal_price update_date  arrival_month arrival_day
# 0    40000.0      40000.0         NaT              1      Sunday
# 1    12000.0      11000.0         NaT              2      Sunday
# 2    40000.0      35000.0         NaT              1      Friday
# 3    25000.0      20000.0         NaT              5      Friday
# 4    35000.0      25000.0         NaT             12     Tuesday

# %%
comd['arrival_month'] = comd.arrival_date.dt.month

# %%
comd.dtypes
# Out:
# state                    object
# district                 object
# market                   object
# commodity                object
# variety                  object
# arrival_date     datetime64[ns]
# min_price               float64
# max_price               float64
# modal_price             float64
# update_date      datetime64[ns]
# arrival_month             int32
# arrival_day              object
# dtype: object

# %%
comd['arrival_day'] = comd.arrival_date.dt.day_name()

# %%
comd.groupby(['state']).district.value_counts()
# Out:
# state           district
# andhra pradesh  guntur             880
#                 cuddapah           362
#                 kurnool             36
# bihar           araria             180
#                 west chambaran     150
#                                   ...
# uttrakhand      dehradoon          462
#                 udhamsinghnagar    398
#                 haridwar           236
#                 nanital             82
# west bengal     murshidabad        624
# Name: count, Length: 239, dtype: int64

# %%
comd.groupby(['commodity']).min_price.mean().round(1)
# Out:
# commodity
# BULL            21846.2
# Bull            18547.6
# Copra            8507.4
# Copraa           5600.0
# Copraa/         13520.0
# DRYCHILLY       23357.1
# Dry Chillies    15661.3
# Dry Chilly      22153.8
# Duck              493.1
# Egg               814.9
# Eggs              600.0
# Grapee           8583.3
# Grapes           5297.9
# Green Fodder      187.3
# GreenFodder       228.0
# Jasmin            167.1
# Jasmine          7476.1
# Jasmyne           238.6
# Rubber          15518.7
# Sugarcane         510.0
# TURMERIC         8500.0
# Turmerc          5786.4
# Turmeric         5780.4
# Name: min_price, dtype: float64
